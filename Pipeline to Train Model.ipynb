# %%
import os
import requests
import cv2
import argparse
import warnings
import numpy as np
import random
import math
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
from copy import deepcopy
from itertools import cycle
from multiprocessing import Pool
from pdf2image import convert_from_path
from pdf2image.exceptions import PDFInfoNotInstalledError
from typing import List, Tuple
from PIL import Image
from decimer_segmentation.complete_structure import complete_structure_mask
from decimer_segmentation.mrcnn.config import Config
from decimer_segmentation.mrcnn import model as modellib
from decimer_segmentation.mrcnn import visualize
from decimer_segmentation.mrcnn import moldetect
from decimer_segmentation.mrcnn import utils
# Out:
# 2023-12-08 17:38:19.183873: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-08 17:38:19.328685: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/raziel/Documents/Datyra/DECIMER-Image-Segmentation/env_37/lib/python3.7/site-packages/cv2/../../lib64:
# 2023-12-08 17:38:19.328707: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-12-08 17:38:19.355414: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-08 17:38:20.044958: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/raziel/Documents/Datyra/DECIMER-Image-Segmentation/env_37/lib/python3.7/site-packages/cv2/../../lib64:
# 2023-12-08 17:38:20.045066: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/raziel/Documents/Datyra/DECIMER-Image-Segmentation/env_37/lib/python3.7/site-packages/cv2/../../lib64:
# 2023-12-08 17:38:20.045078: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-12-08 17:38:20.713551: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-12-08 17:38:20.713587: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: raziel-GV62-8RC
# 2023-12-08 17:38:20.713595: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: raziel-GV62-8RC
# 2023-12-08 17:38:20.713690: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.223.2
# 2023-12-08 17:38:20.713717: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.223.2
# 2023-12-08 17:38:20.713724: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 470.223.2
# Downloading model weights...
# Successfully downloaded the segmentation model weights!
# 2023-12-08 17:38:49.154964: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /home/raziel/Documents/Datyra/DECIMER-Image-Segmentation/env_37/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
class InferenceConfig(moldetect.MolDetectConfig):
    """
    Inference configuration class for MRCNN
    """

    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()

# %%
# Define directory with trained model weights
model_path = 'decimer_segmentation/mask_rcnn_molecule.h5'

# %%
# Download trained weights if needed
if not os.path.exists(model_path):
    print("Downloading model weights...")
    url = "https://zenodo.org/records/10142866/files/mask_rcnn_molecule.h5?download=1"
    req = requests.get(url, allow_redirects=True)
    with open(model_path, "wb") as model_file:
        model_file.write(req.content)
    print("Successfully downloaded the segmentation model weights!")
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=".", config=config)

# Load weights
model.load_weights(model_path, by_name=True)

# %% [markdown]
# # Process to Train

# %%
class TrainConfig(moldetect.MolDetectConfig):
    """
    Traning configuration class for MRCNN
    """

    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 4

config = TrainConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     4
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 4
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           Molecule
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
# Create model in training mode
model_train = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=".")

# %%
# Load weights
model_train.load_weights(model_path, by_name=True)

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# # Dataset Toy Test
# Create a synthetic dataset
#
# Extend the Dataset class and add a method to load the shapes dataset, load_shapes(), and override the following methods:
#
# * load_image()
# * load_mask()
# * image_reference()

# %%
class ShapesDataset(utils.Dataset):
    """Generates the shapes synthetic dataset. The dataset consists of simple
    shapes (triangles, squares, circles) placed randomly on a blank surface.
    The images are generated on the fly. No file access required.
    """

    def load_shapes(self, count, height, width):
        """Generate the requested number of synthetic images.
        count: number of images to generate.
        height, width: the size of the generated images.
        """
        # Add classes
        self.add_class("shapes", 1, "square")
        self.add_class("shapes", 2, "circle")
        self.add_class("shapes", 3, "triangle")

        # Add images
        # Generate random specifications of images (i.e. color and
        # list of shapes sizes and locations). This is more compact than
        # actual images. Images are generated on the fly in load_image().
        for i in range(count):
            bg_color, shapes = self.random_image(height, width)
            self.add_image("shapes", image_id=i, path=None,
                           width=width, height=height,
                           bg_color=bg_color, shapes=shapes)

    def load_image(self, image_id):
        """Generate an image from the specs of the given image ID.
        Typically this function loads the image from a file, but
        in this case it generates the image on the fly from the
        specs in image_info.
        """
        info = self.image_info[image_id]
        bg_color = np.array(info['bg_color']).reshape([1, 1, 3])
        image = np.ones([info['height'], info['width'], 3], dtype=np.uint8)
        image = image * bg_color.astype(np.uint8)
        for shape, color, dims in info['shapes']:
            image = self.draw_shape(image, shape, dims, color)
        return image

    def image_reference(self, image_id):
        """Return the shapes data of the image."""
        info = self.image_info[image_id]
        if info["source"] == "shapes":
            return info["shapes"]
        else:
            super(self.__class__).image_reference(self, image_id)

    def load_mask(self, image_id):
        """Generate instance masks for shapes of the given image ID.
        """
        info = self.image_info[image_id]
        shapes = info['shapes']
        count = len(shapes)
        mask = np.zeros([info['height'], info['width'], count], dtype=np.uint8)
        for i, (shape, _, dims) in enumerate(info['shapes']):
            mask[:, :, i:i+1] = self.draw_shape(mask[:, :, i:i+1].copy(),
                                                shape, dims, 1)
        # Handle occlusions
        occlusion = np.logical_not(mask[:, :, -1]).astype(np.uint8)
        for i in range(count-2, -1, -1):
            mask[:, :, i] = mask[:, :, i] * occlusion
            occlusion = np.logical_and(occlusion, np.logical_not(mask[:, :, i]))
        # Map class names to class IDs.
        class_ids = np.array([self.class_names.index(s[0]) for s in shapes])
        return mask.astype(np.bool), class_ids.astype(np.int32)

    def draw_shape(self, image, shape, dims, color):
        """Draws a shape from the given specs."""
        # Get the center x, y and the size s
        x, y, s = dims
        if shape == 'square':
            cv2.rectangle(image, (x-s, y-s), (x+s, y+s), color, -1)
        elif shape == "circle":
            cv2.circle(image, (x, y), s, color, -1)
        elif shape == "triangle":
            points = np.array([[(x, y-s),
                                (x-s/math.sin(math.radians(60)), y+s),
                                (x+s/math.sin(math.radians(60)), y+s),
                                ]], dtype=np.int32)
            cv2.fillPoly(image, points, color)
        return image

    def random_shape(self, height, width):
        """Generates specifications of a random shape that lies within
        the given height and width boundaries.
        Returns a tuple of three valus:
        * The shape name (square, circle, ...)
        * Shape color: a tuple of 3 values, RGB.
        * Shape dimensions: A tuple of values that define the shape size
                            and location. Differs per shape type.
        """
        # Shape
        shape = random.choice(["square", "circle", "triangle"])
        # Color
        color = tuple([random.randint(0, 255) for _ in range(3)])
        # Center x, y
        buffer = 20
        y = random.randint(buffer, height - buffer - 1)
        x = random.randint(buffer, width - buffer - 1)
        # Size
        s = random.randint(buffer, height//4)
        return shape, color, (x, y, s)

    def random_image(self, height, width):
        """Creates random specifications of an image with multiple shapes.
        Returns the background color of the image and a list of shape
        specifications that can be used to draw the image.
        """
        # Pick random background color
        bg_color = np.array([random.randint(0, 255) for _ in range(3)])
        # Generate a few random shapes and record their
        # bounding boxes
        shapes = []
        boxes = []
        N = random.randint(1, 4)
        for _ in range(N):
            shape, color, dims = self.random_shape(height, width)
            shapes.append((shape, color, dims))
            x, y, s = dims
            boxes.append([y-s, x-s, y+s, x+s])
        # Apply non-max suppression wit 0.3 threshold to avoid
        # shapes covering each other
        keep_ixs = utils.non_max_suppression(np.array(boxes), np.arange(N), 0.3)
        shapes = [s for i, s in enumerate(shapes) if i in keep_ixs]
        return bg_color, shapes

# %%
# Training dataset
dataset_train = ShapesDataset()
dataset_train.load_shapes(500, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_train.prepare()

# Validation dataset
dataset_val = ShapesDataset()
dataset_val.load_shapes(50, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_val.prepare()

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model_train.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=1, 
            layers='heads')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7841/521367616.py in <module>
#       6             learning_rate=config.LEARNING_RATE,
#       7             epochs=1,
# ----> 8             layers='heads')
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/decimer_segmentation/mrcnn/model.py in train(self, train_dataset, val_dataset, learning_rate, epochs, layers, augmentation, custom_callbacks, no_augmentation_sources)
#    2688         log("Checkpoint Path: {}".format(self.checkpoint_path))
#    2689         self.set_trainable(layers)
# -> 2690         self.compile(learning_rate, self.config.LEARNING_MOMENTUM)
#    2691
#    2692         # Work-around for Windows: Keras fails on Windows when using
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/decimer_segmentation/mrcnn/model.py in compile(self, learning_rate, momentum)
#    2493             if "gamma" not in w.name and "beta" not in w.name
#    2494         ]
# -> 2495         self.keras_model.add_loss(tf.add_n(reg_losses))
#    2496
#    2497         # Compile
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/env_tl_37/lib/python3.7/site-packages/keras/engine/base_layer_v1.py in add_loss(self, losses, inputs)
#    1154             for symbolic_loss in symbolic_losses:
#    1155                 if getattr(self, "_is_graph_network", False):
# -> 1156                     self._graph_network_add_loss(symbolic_loss)
#    1157                 else:
#    1158                     # Possible a loss was added in a Layer's `build`.
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/env_tl_37/lib/python3.7/site-packages/keras/engine/functional.py in _graph_network_add_loss(self, symbolic_loss)
#     987     def _graph_network_add_loss(self, symbolic_loss):
#     988         new_nodes, new_layers = _map_subgraph_network(
# --> 989             self.inputs, [symbolic_loss]
#     990         )
#     991         # Losses must be keyed on inputs no matter what in order to be supported
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/env_tl_37/lib/python3.7/site-packages/keras/engine/functional.py in _map_subgraph_network(inputs, outputs)
#    1241     """
#    1242     if not tf.compat.v1.executing_eagerly_outside_functions():
# -> 1243         base_layer_utils.create_keras_history(outputs)
#    1244     # Keep only nodes and layers in the topology between inputs and outputs.
#    1245     _, nodes_by_depth, layers, _ = _map_graph_network(inputs, outputs)
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/env_tl_37/lib/python3.7/site-packages/keras/engine/base_layer_utils.py in create_keras_history(tensors)
#     205         the raw Tensorflow operations.
#     206     """
# --> 207     _, created_layers = _create_keras_history_helper(tensors, set(), [])
#     208     return created_layers
#     209
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/env_tl_37/lib/python3.7/site-packages/keras/engine/base_layer_utils.py in _create_keras_history_helper(tensors, processed_ops, created_layers)
#     289                     else:
#     290                         with tf.init_scope():
# --> 291                             constants[i] = backend.function([], op_input)([])
#     292             layer_inputs = unnest_if_single_tensor(layer_inputs)
#     293             processed_ops, created_layers = _create_keras_history_helper(
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/env_tl_37/lib/python3.7/site-packages/keras/backend.py in __call__(self, inputs)
#    4573             or session != self._session
#    4574         ):
# -> 4575             self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
#    4576
#    4577         fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/env_tl_37/lib/python3.7/site-packages/keras/backend.py in _make_callable(self, feed_arrays, feed_symbols, symbol_vals, session)
#    4500             callable_opts.run_options.CopyFrom(self.run_options)
#    4501         # Create callable.
# -> 4502         callable_fn = session._make_callable_from_options(callable_opts)
#    4503         # Cache parameters corresponding to the generated callable, so that
#    4504         # we can detect future mismatches and refresh the callable.
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/env_tl_37/lib/python3.7/site-packages/tensorflow/python/client/session.py in _make_callable_from_options(self, callable_options)
#    1511       A handle to the new callable.
#    1512     """
# -> 1513     self._extend_graph()
#    1514     return BaseSession._Callable(self, callable_options)
#    1515
#
# ~/Documents/Datyra/Repositorios/DECIMER-Image-Segmentation/env_tl_37/lib/python3.7/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1399   def _extend_graph(self):
#    1400     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1401       tf_session.ExtendSession(self._session)
#    1402
#    1403   # The threshold to run garbage collection to delete dead tensors.
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

# %%
dir = "./dataset/train/instances_default.json"

# %%
coco=COCO(dir)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('COCO categories: \n{}\n'.format(' '.join(nms)))

nms = set([cat['supercategory'] for cat in cats])
print('COCO supercategories: \n{}'.format(' '.join(nms)))
# Out:
# COCO categories:
# bar diagram graph growth pie flow
#
# COCO supercategories:

# %%
# get all images containing given categories, select one at random
catIds = coco.getCatIds(catNms=['bar', 'diagram', 'flow', 'graph', 'growth', 'pie'])
catIds
# imgIds = coco.getImgIds(catIds=catIds );
# imgIds = coco.getImgIds(imgIds = [324158])
# img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
imgIds = coco.getImgIds(catIds=catIds )
imgIds
# Out:
# []

# %%
imgIds = coco.getImgIds(catIds=catIds );
imgIds = coco.getImgIds(imgIds = [1])
img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]

# %%
img
# Out:
# {'id': 1,
#  'width': 960,
#  'height': 720,
#  'file_name': 'bar_chart_0006-006-Stolbchataja-diagramma.jpg.jpg',
#  'license': 0,
#  'flickr_url': '',
#  'coco_url': '',
#  'date_captured': 0}

# %%
img['file_name']
# Out:
# 'bar_chart_0006-006-Stolbchataja-diagramma.jpg.jpg'

# %%
I = io.imread("dataset/train/"+img['file_name'])
plt.axis('off')
plt.imshow(I)
plt.show()

# %%
annIds = coco.getAnnIds(imgIds=img['id'], catIds=catIds, iscrowd=None)
anns = coco.loadAnns(annIds)
anns
# Out:
# [{'id': 1,
#   'image_id': 1,
#   'category_id': 1,
#   'segmentation': [],
#   'area': 165093.7391,
#   'bbox': [206.06, 321.36, 499.21, 330.71],
#   'iscrowd': 0,
#   'attributes': {'occluded': False, 'rotation': 0.0}}]

# %%
#load and display instance annotations
plt.imshow(I); plt.axis('off')
annIds = coco.getAnnIds(imgIds=img['id'], catIds=catIds, iscrowd=None)
anns = coco.loadAnns(annIds)
coco.showAnns(anns,draw_bbox=True)
